# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline

import plotly
import plotly.express as px
import plotly.graph_objects as go
import cufflinks as cf
import plotly.offline as pyo
from plotly.offline import init_notebook_mode,plot,iplot

import folium

# %%
pyo.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.read_excel(r"Covid cases in India.xlsx")
df
# Out:
#     S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0        1     Andhra Pradesh                                       12
# 1        2       Chhattisgarh                                        6
# 2        3              Delhi                                       38
# 3        4            Gujarat                                       43
# 4        5            Haryana                                       16
# 5        6   Himachal Pradesh                                        4
# 6        7          Karnataka                                       20
# 7        8             Kerala                                      131
# 8        9     Madhya Pradesh                                       23
# 9       10        Maharashtra                                      144
# 10      11             Odisha                                        3
# 11      12         Puducherry                                        1
# ...

# %%
df.drop(['S. No.'],axis=1,inplace=True)

# %%
df['Total Cases']=df['Total Confirmed cases (Indian National)']+df['Total Confirmed cases ( Foreign National )']

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# ...

# %%
total_cases_overall = df['Total Cases'].sum()

# %%
total_cases_overall
# Out:
# 729

# %%
print('The total number of cases till 27th march in India is',total_cases_overall)
# Out:
# The total number of cases till 27th march in India is 729

# %%
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_c771b51e_8857_11ea_94c0_82460fcb9accrow0_col1 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_c771b51e_8857_11ea_94c0_82460fcb9accrow0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c771b51e_8857_11ea_94c0_82460fcb9accrow0_col3 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_c771b51e_8857_11ea_94c0_82460fcb9accrow0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_c771b51e_8857_11ea_94c0_82460fcb9accrow0_col5 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_c771b51e_8857_11ea_94c0_82460fcb9accrow1_col1 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_c771b51e_8857_11ea_94c0_82460fcb9accrow1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
# ...

# %%
Total_Active_Cases=df.groupby('Name of State / UT')['Total Cases'].sum().sort_values(ascending=False).to_frame()

# %%
Total_Active_Cases
# Out:
#                     Total Cases
# Name of State / UT
# Maharashtra                 147
# Kerala                      138
# Telengana                    45
# Uttar Pradesh                43
# Rajasthan                    43
# Gujarat                      43
# Delhi                        39
# Tamil Nadu                   35
# Haryana                      30
# Punjab                       29
# Madhya Pradesh               23
# Karnataka                    20
# Jammu and Kashmir            18
# Ladakh                       13
# Andhra Pradesh               12
# West Bengal                  11
# Chandigarh                    7
# Bihar                         7
# Goa                           6
# Chhattisgarh                  6
# Uttarakhand                   4
# Himachal Pradesh              4
# Odisha                        3
# Manipur                       1
# Mizoram                       1
# Puducherry                    1

# %%
Total_Active_Cases.style.background_gradient(cmap='Oranges')
# Out:
# <style  type="text/css" >
#     #T_8d27736e_8858_11ea_a62a_82460fcb9accrow0_col0 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_8d27736e_8858_11ea_a62a_82460fcb9accrow1_col0 {
#             background-color:  #912e04;
#             color:  #f1f1f1;
#         }    #T_8d27736e_8858_11ea_a62a_82460fcb9accrow2_col0 {
#             background-color:  #fdc28b;
#             color:  #000000;
#         }    #T_8d27736e_8858_11ea_a62a_82460fcb9accrow3_col0 {
#             background-color:  #fdc692;
#             color:  #000000;
#         }    #T_8d27736e_8858_11ea_a62a_82460fcb9accrow4_col0 {
#             background-color:  #fdc692;
#             color:  #000000;
#         }    #T_8d27736e_8858_11ea_a62a_82460fcb9accrow5_col0 {
#             background-color:  #fdc692;
#             color:  #000000;
#         }    #T_8d27736e_8858_11ea_a62a_82460fcb9accrow6_col0 {
#             background-color:  #fdce9e;
#             color:  #000000;
# ...

# %% [markdown]
# ## __Graphical Representation__

# %% [markdown]
# #### Pandas Visualisation

# %%
df.plot(kind='bar',x='Name of State / UT',y='Total Cases')
plt.show()
#Plotly
df.iplot(kind='bar',x='Name of State / UT',y='Total Cases')
# Out:
# <div>
#
#
#             <div id="480db333-1e6c-4aeb-8403-c3490e1fe6d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("480db333-1e6c-4aeb-8403-c3490e1fe6d6")) {
#                     Plotly.newPlot(
#                         '480db333-1e6c-4aeb-8403-c3490e1fe6d6',
# ...

# %%
px.bar(df,x='Name of State / UT',y='Total Cases')
# Out:
# <div>
#
#
#             <div id="88871e12-fd4f-4bcf-94f7-9fc8ed663643" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("88871e12-fd4f-4bcf-94f7-9fc8ed663643")) {
#                     Plotly.newPlot(
#                         '88871e12-fd4f-4bcf-94f7-9fc8ed663643',
# ...

# %%
#df.plot(kind='scatter',x='Name of State / UT',y='Total Cases')

# %%
plt.scatter(df['Name of State / UT'],df['Total Cases'])

# %%
df.iplot(kind='scatter',x='Name of State / UT',y='Total Cases',mode='markers+lines',title='My Graph',xTitle='Name of State / UT',yTitle='Total Cases',colors='red',size=20)
# Out:
# <div>
#
#
#             <div id="b5f03904-995b-429d-ae57-8a9d0b11d2db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b5f03904-995b-429d-ae57-8a9d0b11d2db")) {
#                     Plotly.newPlot(
#                         'b5f03904-995b-429d-ae57-8a9d0b11d2db',
# ...

# %%
px.scatter(df,x='Name of State / UT',y='Total Cases')
# Out:
# <div>
#
#
#             <div id="14fc1a39-7d78-46d7-9a87-50c027cba102" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("14fc1a39-7d78-46d7-9a87-50c027cba102")) {
#                     Plotly.newPlot(
#                         '14fc1a39-7d78-46d7-9a87-50c027cba102',
# ...

# %%
#oo vis Total Cases

# %%
#Matplotlib
fig=plt.figure(figsize=(20,10),dpi=200)
axes=fig.add_axes([0,0,1,1])
axes.bar(df['Name of State / UT'],df['Total Cases'])
axes.set_title("Total Cases in India")
axes.set_xlabel('Name of State / UT')
axes.set_ylabel("Total Cases")
plt.show()

#Plotly
fig=go.Figure()
fig.add_trace(go.Bar(x=df['Name of State / UT'],y=df['Total Cases']))
fig.update_layout(title='Total Cases in India',xaxis=dict(title='Name of State / UT'),yaxis=dict(title='Total Cases'))
# Out:
# <div>
#
#
#             <div id="631f0d4e-e793-41d0-a9b8-c9947f24503b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("631f0d4e-e793-41d0-a9b8-c9947f24503b")) {
#                     Plotly.newPlot(
#                         '631f0d4e-e793-41d0-a9b8-c9947f24503b',
#                         [{"type": "bar", "x": ["Andhra Pradesh", "Chhattisgarh", "Delhi", "Gujarat", "Haryana", "Himachal Pradesh", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Tamil Nadu", "Telengana", "Chandigarh", "Jammu and Kashmir", "Ladakh", "Uttar Pradesh", "Uttarakhand", "West Bengal", "Bihar", "Mizoram", "Goa", "Manipur"], "y": [12, 6, 39, 43, 30, 4, 20, 138, 23, 147, 3, 1, 29, 43, 35, 45, 7, 18, 13, 43, 4, 11, 7, 1, 6, 1]}],
# ...

# %%
Indian_Cord = pd.read_excel(r'Indian Coordinates.xlsx')

# %%
Indian_Cord
# Out:
#                       Name of State / UT   Latitude  Longitude
# 0                   Andaman And Nicobar   11.667026  92.735983
# 1                         Andhra Pradesh  14.750429  78.570026
# 2                     Arunachal Pradesh   27.100399  93.616601
# 3                                 Assam   26.749981  94.216667
# 4                                 Bihar   25.785414  87.479973
# 5                            Chandigarh   30.719997  76.780006
# 6                          Chhattisgarh   22.090420  82.159987
# 7                Dadra And Nagar Haveli   20.266578  73.016618
# 8                                  Delhi  28.669993  77.230004
# 9                                   Goa   15.491997  73.818001
# 10                               Haryana  28.450006  77.019991
# 11                     Himachal Pradesh   31.100025  77.166597
# 12  Union Territory of Jammu and Kashmir  33.450000  76.240000
# 13                            Jharkhand   23.800393  86.419986
# ...

# %%
df_full=pd.merge(Indian_Cord,df,on="Name of State / UT")

# %%
df_full
# Out:
#    Name of State / UT   Latitude  Longitude  \
# 7           Rajasthan  26.449999  74.639981
# 8           Telengana  18.112400  79.019300
# 9          Tamil Nadu  12.920386  79.150042
# 10      Uttar Pradesh  27.599981  78.050006
# 11        Uttarakhand  30.320409  78.050006
#
#     Total Confirmed cases (Indian National)  \
# 7                                        41
# 8                                        34
# 9                                        32
# 10                                       42
# 11                                        4
#
#     Total Confirmed cases ( Foreign National )  Cured  Death  Total Cases
# 7                                            2      3      0           43
# 8                                           11      1      0           45
# 9                                            3      1      1           35
# 10                                           1     11      0           43
# ...

# %%
map=folium.Map(location=[20,70],zoom_start=4,tiles='Stamenterrain')

for lat,long,value, name in zip(df_full['Latitude'],df_full['Longitude'],df_full['Total Cases'],df_full['Name of State / UT']):
    folium.CircleMarker([lat,long],radius=value*0.2,popup=('<strong>State</strong>: '+str(name).capitalize()+'<br>''<strong>Total Cases</strong>: ' + str(value)+ '<br>'),color='red',fill_color='red',fill_opacity=0.1).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Global rising of Pandemic

# %%
dbd_India=pd.read_excel(r"per_day_cases.xlsx",parse_dates=True,sheet_name="India")

# %%
dbd_Wuhan=pd.read_excel(r"per_day_cases.xlsx",parse_dates=True,sheet_name="Wuhan")
dbd_Italy=pd.read_excel(r"per_day_cases.xlsx",parse_dates=True,sheet_name="Italy")
dbd_Korea=pd.read_excel(r"per_day_cases.xlsx",parse_dates=True,sheet_name="Korea")

# %%
dbd_India
# Out:
#          Date  Total Cases  New Cases  Days after surpassing 100 cases
# 0  2020-01-30            1          1                              NaN
# 1  2020-01-31            1          0                              NaN
# 2  2020-02-01            1          0                              NaN
# 3  2020-02-02            2          1                              NaN
# 4  2020-02-03            3          1                              NaN
# 5  2020-02-04            3          0                              NaN
# 6  2020-02-05            3          0                              NaN
# 7  2020-02-06            3          0                              NaN
# 8  2020-02-07            3          0                              NaN
# 9  2020-02-08            3          0                              NaN
# 10 2020-02-09            3          0                              NaN
# 11 2020-02-10            3          0                              NaN
# ...

# %%
dbd_Wuhan
# Out:
#          Date  Total Cases  New Cases
# 0  2020-01-22          444          0
# 1  2020-01-23          444          0
# 2  2020-01-24          549        105
# 3  2020-01-25          761        212
# 4  2020-01-26         1058        297
# 5  2020-01-27         1423        365
# 6  2020-01-28         3554       2131
# 7  2020-01-29         3554          0
# 8  2020-01-30         4903       1349
# 9  2020-01-31         5806        903
# 10 2020-01-02         7153       1347
# 11 2020-02-02        11177       4024
# 12 2020-02-03        13522       2345
# 13 2020-02-04        16678       3156
# 14 2020-02-05        19665       2987
# 15 2020-02-06        22112       2447
# 16 2020-02-07        24953       2841
# 17 2020-02-08        27100       2147
# 18 2020-02-09        29631       2531
# 19 2020-02-10        31728       2097
# 20 2020-02-11        33366       1638
# 21 2020-02-12        33366          0
# 22 2020-02-13        48206      14840
# 23 2020-02-14        54406       6200
# ...

# %%
dbd_Italy
# Out:
#          Date  Total Cases  New Cases  Days after surpassing 100 cases
# 0  2020-01-31            2          2                              NaN
# 1  2020-02-01            2          0                              NaN
# 2  2020-02-02            2          0                              NaN
# 3  2020-02-03            2          0                              NaN
# 4  2020-02-04            2          0                              NaN
# 5  2020-02-05            2          0                              NaN
# 6  2020-02-06            3          1                              NaN
# 7  2020-02-07            3          0                              NaN
# 8  2020-02-08            3          0                              NaN
# 9  2020-02-09            3          0                              NaN
# 10 2020-02-10            3          0                              NaN
# 11 2020-02-11            3          0                              NaN
# ...

# %%
dbd_Korea
# Out:
#          Date  Total Cases  New Cases  Days after surpassing 100 cases
# 0  2020-01-20            1          1                              NaN
# 1  2020-01-21            1          0                              NaN
# 2  2020-01-22            1          0                              NaN
# 3  2020-01-23            1          0                              NaN
# 4  2020-01-24            2          1                              NaN
# 5  2020-01-25            2          0                              NaN
# 6  2020-01-26            3          1                              NaN
# 7  2020-01-27            4          1                              NaN
# 8  2020-01-28            4          0                              NaN
# 9  2020-01-29            4          0                              NaN
# 10 2020-01-30            6          2                              NaN
# 11 2020-01-31           11          5                              NaN
# ...

# %%
#Matplotlib
fig = plt.figure(figsize=(10,10),dpi=200)
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.bar(dbd_India["Date"],dbd_India["Total Cases"],color='red')
axes.set_xlabel("Date")
axes.set_ylabel("Total Cases")
axes.set_title("Confirmed cases in India")
plt.show()

# %%
#Plotly Express
fig=px.bar(dbd_India,x="Date",y="Total Cases",color="Total Cases",title="Confirmed cases in India")
fig.show()
# Out:
# <div>
#
#
#             <div id="7c2b385b-01ba-44a6-8cc2-4523a4b73993" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7c2b385b-01ba-44a6-8cc2-4523a4b73993")) {
#                     Plotly.newPlot(
#                         '7c2b385b-01ba-44a6-8cc2-4523a4b73993',
# ...

# %%
#Plotly Express
fig=px.bar(dbd_Wuhan,x="Date",y="Total Cases",color="Total Cases",title="Confirmed cases in Wuhan")
fig.show()
# Out:
# <div>
#
#
#             <div id="7e61259e-3322-43b0-9053-5d6aea4d2717" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e61259e-3322-43b0-9053-5d6aea4d2717")) {
#                     Plotly.newPlot(
#                         '7e61259e-3322-43b0-9053-5d6aea4d2717',
# ...

# %%
#Plotly Express
fig=px.bar(dbd_Italy,x="Date",y="Total Cases",color="Total Cases",title="Confirmed cases in Italy")
fig.show()
# Out:
# <div>
#
#
#             <div id="7fecad67-0c43-48d0-ae4e-89791c4496ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7fecad67-0c43-48d0-ae4e-89791c4496ef")) {
#                     Plotly.newPlot(
#                         '7fecad67-0c43-48d0-ae4e-89791c4496ef',
# ...

# %%
#Plotly Express
fig=px.bar(dbd_Korea,x="Date",y="Total Cases",color="Total Cases",title="Confirmed cases in Korea")
fig.show()
# Out:
# <div>
#
#
#             <div id="18144a4f-812a-4bd2-b0ce-bb3807e51de5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18144a4f-812a-4bd2-b0ce-bb3807e51de5")) {
#                     Plotly.newPlot(
#                         '18144a4f-812a-4bd2-b0ce-bb3807e51de5',
# ...

# %%
fig=plt.figure(figsize=(10,5),dpi=200)
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(dbd_India["Date"],dbd_India["Total Cases"],color='green',marker='*')
axes.set_xlabel("Date")
axes.set_ylabel("Total Cases")
axes.set_title("Confirmed cases in India")
plt.show()

# %%
#Plotly Express
fig=px.scatter(dbd_India,x="Date",y="Total Cases",color="Total Cases",title="Confirmed Cases in India till 21st March 2020")
fig.show()
# Out:
# <div>
#
#
#             <div id="fb6b4e9c-f836-426e-a021-d8c5be55aa63" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fb6b4e9c-f836-426e-a021-d8c5be55aa63")) {
#                     Plotly.newPlot(
#                         'fb6b4e9c-f836-426e-a021-d8c5be55aa63',
# ...

# %%
#Plotly
dbd_India.iplot(kind='scatter',x='Date',y='Total Cases',mode='lines+markers')
# Out:
# <div>
#
#
#             <div id="0f91894b-1472-4ce2-b122-a0a67037ba8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0f91894b-1472-4ce2-b122-a0a67037ba8e")) {
#                     Plotly.newPlot(
#                         '0f91894b-1472-4ce2-b122-a0a67037ba8e',
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=dbd_India["Date"],y=dbd_India["Total Cases"],mode='lines+markers'))
# Out:
# <div>
#
#
#             <div id="6ffcc80e-e13c-4d0b-be67-54d3df91d9d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6ffcc80e-e13c-4d0b-be67-54d3df91d9d0")) {
#                     Plotly.newPlot(
#                         '6ffcc80e-e13c-4d0b-be67-54d3df91d9d0',
# ...

# %% [markdown]
# ## Subplots using Bar Graph

# %%
from plotly.subplots import make_subplots

# %%
fig=make_subplots(
    rows=2,cols=2,
    specs=[[{"secondary_y":True},{"secondary_y":True}],[{"secondary_y":True},{"secondary_y":True}]],
    subplot_titles=("S.Korea","Italy","India","Wuhan"))

fig.add_trace(go.Bar(x=dbd_Korea['Date'],y=dbd_Korea['Total Cases'],
                    marker=dict(color=dbd_Korea['Total Cases'],coloraxis="coloraxis")),1,1)

fig.add_trace(go.Bar(x=dbd_Italy['Date'],y=dbd_Italy['Total Cases'],
                    marker=dict(color=dbd_Italy['Total Cases'],coloraxis="coloraxis")),1,2)

fig.add_trace(go.Bar(x=dbd_India['Date'],y=dbd_India['Total Cases'],
                    marker=dict(color=dbd_India['Total Cases'],coloraxis="coloraxis")),2,1)

fig.add_trace(go.Bar(x=dbd_Wuhan['Date'],y=dbd_Wuhan['Total Cases'],
                    marker=dict(color=dbd_Wuhan['Total Cases'],coloraxis="coloraxis")),2,2)



fig.update_layout(coloraxis=dict(colorscale='Bluered_r'),showlegend=False,title_text="Total Cases in 4 Countries")

fig.update_layout(plot_bgcolor='rgb(230,230,230)')
# Out:
# <div>
#
#
#             <div id="449f4a33-b51e-4397-a04e-8a7090d8a7e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("449f4a33-b51e-4397-a04e-8a7090d8a7e5")) {
#                     Plotly.newPlot(
#                         '449f4a33-b51e-4397-a04e-8a7090d8a7e5',
# ...

# %%
fig=make_subplots(
    rows=2,cols=2,
    specs=[[{"secondary_y":True},{"secondary_y":True}],[{"secondary_y":True},{"secondary_y":True}]],
    subplot_titles=("S.Korea","Italy","India","Wuhan"))

fig.add_trace(go.Scatter(x=dbd_Korea['Date'],y=dbd_Korea['Total Cases'],
                    marker=dict(color=dbd_Korea['Total Cases'],coloraxis="coloraxis")),1,1)

fig.add_trace(go.Scatter(x=dbd_Italy['Date'],y=dbd_Italy['Total Cases'],
                    marker=dict(color=dbd_Italy['Total Cases'],coloraxis="coloraxis")),1,2)

fig.add_trace(go.Scatter(x=dbd_India['Date'],y=dbd_India['Total Cases'],
                    marker=dict(color=dbd_India['Total Cases'],coloraxis="coloraxis")),2,1)

fig.add_trace(go.Scatter(x=dbd_Wuhan['Date'],y=dbd_Wuhan['Total Cases'],
                    marker=dict(color=dbd_Wuhan['Total Cases'],coloraxis="coloraxis")),2,2)



fig.update_layout(coloraxis=dict(colorscale='Bluered_r'),showlegend=False,title_text="Total Cases in 4 Countries")

fig.update_layout(plot_bgcolor='rgb(230,230,230)')
# Out:
# <div>
#
#
#             <div id="c333148b-93d2-4486-875c-6c1aebe340fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c333148b-93d2-4486-875c-6c1aebe340fb")) {
#                     Plotly.newPlot(
#                         'c333148b-93d2-4486-875c-6c1aebe340fb',
# ...

# %% [markdown]
# ### World Coronavirus

# %%
df=pd.read_csv('covid_19_data.csv',parse_dates=['Last Update'])

# %%
df.rename(columns={'ObservationDate':'Date','Country/Region':'Country'},inplace=True)

# %%
df
# Out:
#        SNo        Date                Province/State  \
# 0        1  01/22/2020                         Anhui
# 1        2  01/22/2020                       Beijing
# 2        3  01/22/2020                     Chongqing
# 3        4  01/22/2020                        Fujian
# 4        5  01/22/2020                         Gansu
# 5        6  01/22/2020                     Guangdong
# 6        7  01/22/2020                       Guangxi
# 7        8  01/22/2020                       Guizhou
# 8        9  01/22/2020                        Hainan
# 9       10  01/22/2020                         Hebei
# 10      11  01/22/2020                  Heilongjiang
# 11      12  01/22/2020                         Henan
# 12      13  01/22/2020                     Hong Kong
# 13      14  01/22/2020                         Hubei
# 14      15  01/22/2020                         Hunan
# 15      16  01/22/2020                Inner Mongolia
# 16      17  01/22/2020                       Jiangsu
# ...

# %%
df.groupby('Date').sum()
# Out:
#                 SNo  Confirmed  Deaths  Recovered
# Date
# 01/22/2020      741      555.0    17.0       28.0
# 01/23/2020     2829      653.0    18.0       30.0
# 01/24/2020     4305      941.0    26.0       36.0
# 01/25/2020     6490     1438.0    42.0       39.0
# 01/26/2020     9071     2118.0    56.0       52.0
# 01/27/2020    12342     2927.0    82.0       61.0
# 01/28/2020    15262     5578.0   131.0      107.0
# 01/29/2020    18711     6165.0   133.0      126.0
# 01/30/2020    23345     8235.0   171.0      143.0
# 01/31/2020    28675     9925.0   213.0      222.0
# 02/01/2020    35309    12038.0   259.0      284.0
# 02/02/2020    39798    16787.0   362.0      472.0
# 02/03/2020    44982    19881.0   426.0      623.0
# 02/04/2020    51135    23892.0   492.0      852.0
# 02/05/2020    56871    27636.0   564.0     1124.0
# 02/06/2020    61912    30818.0   634.0     1487.0
# 02/07/2020    67932    34392.0   719.0     2011.0
# 02/08/2020    73116    37121.0   806.0     2616.0
# ...

# %%
confirmed=df.groupby('Date').sum()['Confirmed'].reset_index()
death=df.groupby('Date').sum()['Deaths'].reset_index()
rec=df.groupby('Date').sum()['Recovered'].reset_index()

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=confirmed['Date'],y=confirmed['Confirmed'],mode='lines+markers',name='Confirmed',line=dict(color='blue',width=2)))

fig.add_trace(go.Scatter(x=death['Date'],y=death['Deaths'],mode='lines+markers',name='Deaths',line=dict(color='red',width=2)))
fig.add_trace(go.Scatter(x=rec['Date'],y=rec['Recovered'],mode='lines+markers',name='Recovered',line=dict(color='green',width=2)))
# Out:
# <div>
#
#
#             <div id="d4cf7622-c6e4-46cf-8ce2-bce88a4144ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d4cf7622-c6e4-46cf-8ce2-bce88a4144ae")) {
#                     Plotly.newPlot(
#                         'd4cf7622-c6e4-46cf-8ce2-bce88a4144ae',
# ...
